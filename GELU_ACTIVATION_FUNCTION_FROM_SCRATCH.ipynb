# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansai26/GELU-ACTIVATION-FUNCTION-implementation-from-scratch-FROM-SCRATCH/blob/master/GELU_ACTIVATION_FUNCTION_FROM_SCRATCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GELU ACTIVATION FUNCTION

# %% [markdown]
# $0.5x\left(1+\tanh\left[\sqrt{2/\pi}\left(x + 0.044715x^{3}\right)\right]\right)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import math

# %%
def gelu(x):
  return 0.5*x*(1+np.tanh((np.sqrt(2/math.pi)*x+0.044715*x**3)))

# %%
# plot inputs and outputs
from matplotlib import pyplot
 
# rectified linear function
def gelu(x):
   return 0.5*x*(1+np.tanh((np.sqrt(2/math.pi)*x+0.044715*x**3)))
 
# define a series of inputs
series_in = [x for x in range(-10, 11)]
# calculate outputs for our inputs
series_out = [gelu(x) for x in series_in]
# line plot of raw inputs to rectified outputs
pyplot.plot(series_in, series_out)
pyplot.show()
